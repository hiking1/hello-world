# %% [markdown]
# <a href="https://colab.research.google.com/github/hiking1/hello-world/blob/master/Copy_of_huggingface_course1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------------------
# absl-py                       1.0.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.2.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arviz                         0.11.4
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# atari-py                      0.2.9
# atomicwrites                  1.4.0
# attrs                         21.4.0
# audioread                     2.1.9
# autograd                      1.3
# Babel                         2.9.1
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        4.1.0
# blis                          0.4.1
# bokeh                         2.3.3
# Bottleneck                    1.3.4
# ...

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 3.8 MB 36.1 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 55.6 MB/s
# ...
#      |████████████████████████████████| 67 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 895 kB 58.3 MB/s
# ...
#      |████████████████████████████████| 596 kB 49.9 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
pip install transformers[sentencepiece]
# Out:
# ...
#      |████████████████████████████████| 3.8 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 43.6 MB/s
# ...
#      |████████████████████████████████| 67 kB 3.6 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 35.4 MB/s
# ...
#      |████████████████████████████████| 895 kB 40.5 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 17.1 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from transformers import pipeline

# %%
classifier=pipeline("zero-shot-classification")
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli (https://huggingface.co/facebook/bart-large-mnli)
# Downloading:   0%|          | 0.00/1.13k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
classifier("Fact is morbid risk of illness decreased many years ago",
           candidate_labels=['education','satire','empirical', 'medical','science','history' ])
# Out:
# {'labels': ['history',
#   'empirical',
#   'science',
#   'medical',
#   'education',
#   'satire'],
#  'scores': [0.4266427755355835,
#   0.3778861165046692,
#   0.100428007543087,
#   0.07458122074604034,
#   0.011005512438714504,
#   0.00945635698735714],
#  'sequence': 'Fact is morbid risk of illness decreased many years ago'}

# %%
classifier("Fact is morbid risk of illness decreased",
           candidate_labels=['education','satire','empirical', 'medical','science','history' ])
# Out:
# {'labels': ['empirical',
#   'medical',
#   'science',
#   'history',
#   'education',
#   'satire'],
#  'scores': [0.5209363698959351,
#   0.20050227642059326,
#   0.16332770884037018,
#   0.09118805080652237,
#   0.014679757878184319,
#   0.009365811012685299],
#  'sequence': 'Fact is morbid risk of illness decreased'}
